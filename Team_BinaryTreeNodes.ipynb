# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhi8886/Amazon_ML_Challenge_2k23/blob/main/Team_BinaryTreeNodes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
test_data= pd.read_csv("/content/drive/MyDrive/MLchallenge/datasetb2d9982/dataset/test.csv")

# %%
test_data.head()
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0      604373  Manuel d'Héliogravure Et de Photogravure En Re...
# 1     1729783  DCGARING Microfiber Throw Blanket Warm Fuzzy P...
# 2     1871949  I-Match Auto Parts Front License Plate Bracket...
# 3     1107571  PinMart Gold Plated Excellence in Service 1 Ye...
# 4      624253  Visual Mathematics, Illustrated by the TI-92 a...
#
#                                        BULLET_POINTS  \
# 0                                                NaN
# 1  [QUALITY GUARANTEED: Luxury cozy plush polyest...
# 2  [Front License Plate Bracket Made Of Plastic,D...
# 3  [Available as a single item or bulk packed. Se...
# 4                                                NaN
#
#                                          DESCRIPTION  PRODUCT_TYPE_ID
# 0                                                NaN             6142
# 1  <b>DCGARING Throw Blanket</b><br><br> <b>Size ...             1622
# ...

# %%
train_data= pd.read_csv("/content/drive/MyDrive/MLchallenge/datasetb2d9982/dataset/train.csv")

# %%
train_data.head()
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0     1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1     2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3     1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4      283658  The United Empire Loyalists: A Chronicle of th...
#
#                                        BULLET_POINTS  \
# 0  [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1  [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2  [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3  [Made By 95%cotton and 5% Lycra which gives yo...
# 4                                                NaN
#
#                                          DESCRIPTION  PRODUCT_TYPE_ID  \
# 0                                                NaN             1650
# 1                                                NaN             2755
# ...

# %%
train_data.shape
# Out:
# (2249698, 6)

# %%
test_data.shape
# Out:
# (734736, 5)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2249698 entries, 0 to 2249697
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   PRODUCT_ID       int64
#  1   TITLE            object
#  2   BULLET_POINTS    object
#  3   DESCRIPTION      object
#  4   PRODUCT_TYPE_ID  int64
#  5   PRODUCT_LENGTH   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 103.0+ MB

# %%
train_data.isnull().sum()
# Out:
# PRODUCT_ID               0
# TITLE                   12
# BULLET_POINTS       837364
# DESCRIPTION        1157381
# PRODUCT_TYPE_ID          0
# PRODUCT_LENGTH           0
# dtype: int64

# %%
train_data.describe()
# Out:
#          PRODUCT_ID  PRODUCT_TYPE_ID  PRODUCT_LENGTH
# count  2.249698e+06     2.249698e+06    2.249698e+06
# mean   1.499795e+06     4.000456e+03    4.071839e+03
# std    8.661944e+05     3.966146e+03    1.351685e+06
# min    1.000000e+00     0.000000e+00    1.000000e+00
# 25%    7.494795e+05     2.300000e+02    5.118110e+02
# 50%    1.499558e+06     2.916000e+03    6.630000e+02
# 75%    2.250664e+06     6.403000e+03    1.062992e+03
# max    2.999999e+06     1.342000e+04    1.885801e+09

# %%
train_data.interpolate()
# Out:
#          PRODUCT_ID                                              TITLE  \
# 0           1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1           2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2           2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3           1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4            283658  The United Empire Loyalists: A Chronicle of th...
# ...             ...                                                ...
# 2249693     2422167  Nike Women's As W Ny Df Swsh Hn Kh Bra (CZ7610...
# 2249694     2766635  (3PCS) Goose Game Cute Cartoon Enamel Pins, Fu...
# 2249695     1987786  Kangroo Sweep Movement Printed Wooden Wall Clo...
# 2249696     1165754  Electro Voice EKX-BRKT15 | Wall Mount Bracket ...
# 2249697     1072666  Skyjacker C7360SP Component Box For PN[C7360PK...
#
#                                              BULLET_POINTS  \
# ...

# %%
train_data['TITLE'].fillna('', inplace=True)
train_data
# Out:
#          PRODUCT_ID                                              TITLE  \
# 0           1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1           2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2           2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3           1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4            283658  The United Empire Loyalists: A Chronicle of th...
# ...             ...                                                ...
# 2249693     2422167  Nike Women's As W Ny Df Swsh Hn Kh Bra (CZ7610...
# 2249694     2766635  (3PCS) Goose Game Cute Cartoon Enamel Pins, Fu...
# 2249695     1987786  Kangroo Sweep Movement Printed Wooden Wall Clo...
# 2249696     1165754  Electro Voice EKX-BRKT15 | Wall Mount Bracket ...
# 2249697     1072666  Skyjacker C7360SP Component Box For PN[C7360PK...
#
#                                              BULLET_POINTS  \
# ...

# %%
train_data.isnull().sum()
# Out:
# PRODUCT_ID               0
# TITLE                    0
# BULLET_POINTS       837364
# DESCRIPTION        1157381
# PRODUCT_TYPE_ID          0
# PRODUCT_LENGTH           0
# dtype: int64

# %%
train_data['DESCRIPTION'].fillna('binarytreenodes',inplace=True)
train_data.head()
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0     1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1     2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3     1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4      283658  The United Empire Loyalists: A Chronicle of th...
#
#                                        BULLET_POINTS  \
# 0  [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1  [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2  [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3  [Made By 95%cotton and 5% Lycra which gives yo...
# 4                                                NaN
#
#                                          DESCRIPTION  PRODUCT_TYPE_ID  \
# 0                                    binarytreenodes             1650
# 1                                    binarytreenodes             2755
# ...

# %%
train_data['BULLET_POINTS'].fillna('binarytreenodes',inplace=True)
train_data.head()
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0     1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1     2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3     1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4      283658  The United Empire Loyalists: A Chronicle of th...
#
#                                        BULLET_POINTS  \
# 0  [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1  [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2  [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3  [Made By 95%cotton and 5% Lycra which gives yo...
# 4                                    binarytreenodes
#
#                                          DESCRIPTION  PRODUCT_TYPE_ID  \
# 0                                    binarytreenodes             1650
# 1                                    binarytreenodes             2755
# ...

# %%
train_data.isnull().sum()
# Out:
# PRODUCT_ID         0
# TITLE              0
# BULLET_POINTS      0
# DESCRIPTION        0
# PRODUCT_TYPE_ID    0
# PRODUCT_LENGTH     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest= train_test_split(train_data.iloc[:,1:5], 
                                                  train_data.iloc[:,5], 
                                                  test_size=0.2, 
                                                  random_state=2)

# %%
from xgboost import XGBRegressor

# %%
import numpy as np

# %%
col = train_data['PRODUCT_TYPE_ID'].values

# Convert the integer values to float
col_float = col.astype(np.float32)

# Convert the NumPy array back to a DataFrame column
train_data['PRODUCT_TYPE_ID'] = pd.Series(col_float, index=train_data.index)


col = train_data['PRODUCT_LENGTH'].values

# Convert the integer values to float
col_float = col.astype(np.float32)

# Convert the NumPy array back to a DataFrame column
train_data['PRODUCT_LENGTH'] = pd.Series(col_float, index=train_data.index)


train_data.head()
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0     1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1     2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3     1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4      283658  The United Empire Loyalists: A Chronicle of th...
#
#                                        BULLET_POINTS  \
# 0  [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1  [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2  [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3  [Made By 95%cotton and 5% Lycra which gives yo...
# 4                                    binarytreenodes
#
#                                          DESCRIPTION  PRODUCT_TYPE_ID  \
# 0                                    binarytreenodes           1650.0
# 1                                    binarytreenodes           2755.0
# ...

# %%
xtrain=train_data.drop(['PRODUCT_LENGTH','PRODUCT_ID'], axis=1)

# %%
model=XGBRegressor()
model.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-7e025bf98358> in <cell line: 2>()
#       1 model=XGBRegressor()
# ----> 2 model.fit(xtrain,ytrain)
#
# /usr/local/lib/python3.9/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     986         with config_context(verbosity=self.verbosity):
#     987             evals_result: TrainingCallback.EvalsLog = {}
# ...
